# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
acc_fedavg = [0.010,0.7060, 0.7836, 0.7616, 0.8161, 0.8280]
adv_fedavg = [0.010,0.014, 0.022, 0.028, 0.016, 0.0210]

acc_50 = [0.016,0.0887, 0.5625, 0.6114,0.6861,0.7374]
adv_50 = [0.02,0.0539, 0.0938, 0.1401,0.1905,0.2512]

acc_100 = [37.91, 65.22, 65.13, 71.66, 74.72]
adv_100 = [3.79, 13.68, 20.77, 22.96, 28.52]

acc_200 = [0.012,0.4903, 0.6794, 0.6654, 0.7195, 0.7481]
adv_200 = [0.018,0.0623, 0.1387, 0.2053, 0.2317, 0.2868]

acc_300 = [58.55, 72.17, 73.68, 78.83, 79.60]
adv_300 = [3.74, 5.35, 6.71, 8.38, 12.44]

acc_400 = [0.011,0.6212, 0.7301, 0.7428, 0.7959, 0.8055]
adv_400 = [0.022,0.0313, 0.0533, 0.0603, 0.0728, 0.0914]

acc_500 = [67.01,73.49,74.82,79.83, 80.69]
adv_500 = [0.0,4.81,6.07,7.30, 8.96]

cm_rnds = [0,500,1000,1500,2000,2500]

# %%
plt.figure()

plt.plot(cm_rnds,acc_50,linestyle='--',marker='o',color='#606060', label='jump 50 (acc)')
plt.plot(cm_rnds,adv_50,linestyle='-',marker='+',color='#606060', label= 'jump 50 (adv acc)')

# plt.plot(cm_rnds,acc_100,linestyle='--',marker='o',color='#606060', label='acc (delay 100)')
# plt.plot(cm_rnds,adv_100,linestyle='-',marker='+',color='#606060', label= 'adv acc (delay 100)')

plt.plot(cm_rnds,acc_200,linestyle='--',marker='o',color='#d3763a', label='jump 200 (acc)')
plt.plot(cm_rnds,adv_200,linestyle='-',marker='+',color='#d3763a', label='jump 200 (adv acc)')
         
# plt.plot(cm_rnds,acc_300,linestyle='--',marker='o',color='#3c96d3',label='acc (delay 300)' )
# plt.plot(cm_rnds,adv_300,linestyle='-',marker='+',color='#3c96d3', label='adv acc (delay 300)')

plt.plot(cm_rnds,acc_400,linestyle='--',marker='o',color='#96c727', label='jump 400 (acc)')
plt.plot(cm_rnds,adv_400,linestyle='-',marker='+',color='#96c727', label='jump 400 (adv acc)')


plt.plot(cm_rnds,acc_fedavg,linestyle='--',marker='X', label='FedAvg')


# plt.plot(cm_rnds,acc_400,linestyle='--',marker='o',color='#373d4f', label='acc (delay 400)')
# plt.plot(cm_rnds,adv_400,linestyle='-',marker='+',color='#373d4f', label='adv acc (delay 400)')

# plt.plot(cm_rnds,acc_500,linestyle='--',marker='o',color='#cccc00', label='acc (delay 500)')
# plt.plot(cm_rnds,adv_500,linestyle='-',marker='+',color='#cccc00', label='adv acc (delay 500)')

# plt.legend(loc=(1.07,0.15))
plt.legend(loc=(-0.1,-0.3), fontsize='small', ncol=4)
plt.xlabel('communication rounds')
plt.ylabel('accuracy')
plt.ylim(0.0,1.0)
# plt.title('Effect of delayed training')
plt.savefig('delayed.pdf',bbox_inches='tight')

# %%
acc_200_05 = [0.4903, 0.6794, 0.6654, 0.7195, 0.7481]
adv_200_05 = [0.0623, 0.1387, 0.2053, 0.2317, 0.2868]

acc_200_06 = [4467, 6483, 6456, 7103, 7354]
adv_200_06 = [689, 1628, 2311, 2513, 3054]

acc_200_07 = [0.3942, 0.6155, 0.6283, 0.6994, 0.7323]
adv_200_07 = [0.0655, 0.1858, 0.2380, 0.2627, 0.3123]

acc_200_08 = [3185, 5549, 5938, 6889, 7229]
adv_200_08 = [562, 1792, 2419, 2663, 3369]

acc_200_09 = [0.1691, 0.2534, 0.4546, 0.6217, 0.6553]
adv_200_09 = [0.0515, 0.0710, 0.1708, 0.2386, 0.3061]

acc_200_1 = []
adv_200_1 = []

# %%
plt.figure()
plt.plot(cm_rnds,acc_200_05,linestyle='--',marker='o',color='#606060', label='K/N 0.5 (acc)')
plt.plot(cm_rnds,adv_200_05,linestyle='-',marker='+',color='#606060', label= 'K/N 0.5 (adv acc)')

# plt.plot(cm_rnds,acc_200_06,linestyle='--',marker='o',color='#d3763a', label='max K/N 0.6 (acc)')
# plt.plot(cm_rnds,adv_200_06,linestyle='-',marker='+',color='#d3763a', label='max K/N 0.6 (adv acc)')
         
# plt.plot(cm_rnds,acc_200_07,linestyle='--',marker='o',color='#3c96d3',label='max K/N 0.7 (acc)' )
# plt.plot(cm_rnds,adv_200_07,linestyle='-',marker='+',color='#3c96d3', label='max K/N 0.7 (adv acc)')

plt.plot(cm_rnds,acc_200_07,linestyle='--',marker='o',color='#d3763a', label='K/N 0.7 (acc)')
plt.plot(cm_rnds,adv_200_07,linestyle='-',marker='+',color='#d3763a', label='K/N 0.7 (adv acc)')

plt.plot(cm_rnds,acc_200_09,linestyle='--',marker='o',color='#96c727', label='K/N 0.9 (acc)')
plt.plot(cm_rnds,adv_200_09,linestyle='-',marker='+',color='#96c727', label='K/N 0.9 (adv acc)')

# plt.legend(loc=(1.07,0.15))
plt.legend(loc=(-0.0,-0.3), fontsize='small', ncol=3)
plt.xlabel('communication rounds')
plt.ylabel('accuracy')
plt.ylim(0.0,1.0)
# plt.title('Effect of K/N')
plt.savefig('ratio.pdf',bbox_inches='tight')
